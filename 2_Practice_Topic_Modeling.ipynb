# %% [markdown]
# #**INTELLIGENZA ARTIFICIALE: TECNOLOGIE, MODELLI E APPLICAZIONI**
#
# ---
#
# **Teaching Assistants:** Lorenzo Vaiani
#
# **Practice:** Topic Modeling

# %% [markdown]
# Occurrence-based representations are high-dimensional, what is the dimension of the generated TF-IDF vector representation?
# Topic modeling focuses on capturing latent topics in large document corpora.
#
# The data collection used in this second part of the practice is provided [here](https://raw.githubusercontent.com/MorenoLaQuatra/DeepNLP/main/practices/P1/CovidFake_filtered.csv) - [source: Zenodo](https://zenodo.org/record/4282522#.YVdCXcbOOpd)

# %% [markdown]
# # Exercise 1
#
# Latent Semantic Indexing (LSI) models underlying concepts by using SVD (Singular Value Decomposition).
#
# Use [gensim](https://radimrehurek.com/gensim/) library to:
# 1. Create a corpus composed of the headlines contained in the data collection.
# 2. Generate a [dictionary](https://radimrehurek.com/gensim/corpora/dictionary.html) to create a word -> id mapping (required by LSI module).
# 3. Using the dictionary, preprocess the corpus to obtain the representation required for LSI model training ([documentation here](https://radimrehurek.com/gensim/models/lsimodel.html)).
# 4. Inspect the top-5 topics generated by the LSI model for the analysed corpus.

# %%
! pip uninstall numpy
! pip install numpy==1.26.4
! pip install --upgrade scipy gensim
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Would remove:
#     /usr/local/bin/f2py
#     /usr/local/lib/python3.12/dist-packages/numpy-1.26.4.dist-info/*
#     /usr/local/lib/python3.12/dist-packages/numpy.libs/libgfortran-040039e1.so.5.0.0
#     /usr/local/lib/python3.12/dist-packages/numpy.libs/libopenblas64_p-r0-0cf96a72.3.23.dev.so
#     /usr/local/lib/python3.12/dist-packages/numpy.libs/libquadmath-96973f99.so.0.0.0
#     /usr/local/lib/python3.12/dist-packages/numpy/*
# Proceed (Y/n)? Y
#   Successfully uninstalled numpy-1.26.4
# Collecting numpy==1.26.4
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Collecting scipy
#   Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.0 MB/s eta 0:00:00
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in /usr/local/lib/python3.12/dist-packages (from scipy) (1.26.4)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Downloading scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 54.7 MB/s eta 0:00:00
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 17.2 MB/s eta 0:00:00
# Installing collected packages: scipy, gensim
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed gensim-4.4.0 scipy-1.17.1

# %%
import pandas as pd
df_tmodeling = pd.read_csv('CovidFake_filtered.csv')

# %%
# generating the corpus
corpus = df_tmodeling["headlines"].tolist()
corpus = [s.split() for s in corpus]
print (corpus[:10])
# Out:
# [['A', 'post', 'claims', 'compulsory', 'vacination', 'violates', 'the', 'principles', 'of', 'bioethics,', 'that', 'coronavirus', "doesn't", 'exist,', 'that', 'the', 'PCR', 'test', 'returns', 'many', 'false', 'positives,', 'and', 'that', 'influenza', 'vaccine', 'is', 'related', 'to', 'COVID-19.'], ['A', 'photo', 'claims', 'that', 'this', 'person', 'is', 'a', 'doctor', 'who', 'died', 'after', 'attending', 'to', 'too', 'many', 'COVID-19', 'patinents', 'in', 'Hospital', 'Muñiz', 'in', 'Buenos', 'Aires.'], ['Post', 'about', 'a', 'video', 'claims', 'that', 'it', 'is', 'a', 'protest', 'against', 'confination', 'in', 'the', 'town', 'of', 'Aranda', 'de', 'Duero', '(Burgos)'], ['All', 'deaths', 'by', 'respiratory', 'failure', 'and', 'pneumonia', 'are', 'being', 'registered', 'as', 'COVID-19,', 'according', 'to', 'the', 'Civil', 'Registry', 'website.'], ['The', 'dean', 'of', 'the', 'College', 'of', 'Biologists', 'of', 'Euskadi', 'states', 'that', 'there', 'are', 'a', 'lot', 'of', 'PCR', 'false', 'positives', 'and', 'asymptomatic', "don't", 'spread', 'coronavirus.'], ['Households', 'with', 'COVID-19', 'patients', 'in', 'Porto', 'Alegre,', 'Campo', 'Grande', 'and', 'Santo', 'Antônio', 'da', 'Platina', 'must', 'put', 'a', 'red', 'ribbon', 'on', 'their', 'garbage', 'bags.', 'Garbagemen', 'are', 'instructed', 'to', 'handle', 'them', 'in', 'a', 'safer', 'way'], ['A', 'chain', 'lists', 'recommendations', 'to', 'prevent', 'and', 'treat', 'coronavirus.'], ['60,000', 'Argentinian', 'companies', 'have', 'closed', 'due', 'to', 'COVID-19;', 'also,', 'all', 'companies', 'receiving', 'government', 'aid', 'during', 'the', 'pandemic', 'will', 'be', 'expropriated', 'by', 'the', 'government'], ['Social', 'media', 'posts', 'criticize', 'a', 'photo', 'from', 'smiling', 'president', 'of', 'the', 'Goverment', 'Pedro', 'Sánchez', 'during', 'his', 'holidays', 'after', 'thousands', 'died', 'from', 'COVID-19'], ['CDC', 'has', 'released', 'an', 'update', 'on', 'how', 'the', 'novel', 'coronavirus', 'can', 'be', 'transmitted']]

# %%
# constructing dictionary and processing the corpus
from gensim.corpora.dictionary import Dictionary
tm_dict = Dictionary(corpus)
processed_corpus = [tm_dict.doc2bow(text) for text in corpus]

# %%
# training LSI model
from gensim.models import LsiModel
model = LsiModel(processed_corpus, id2word=tm_dict)
model.print_topics(5)
# Out:
# [(0,
#   '0.636*"the" + 0.389*"of" + 0.314*"in" + 0.280*"a" + 0.254*"to" + 0.179*"and" + 0.155*"that" + 0.121*"is" + 0.107*"coronavirus" + 0.106*"A"'),
#  (1,
#   '-0.629*"the" + 0.598*"a" + 0.386*"in" + 0.105*"A" + 0.097*"and" + 0.078*"has" + 0.077*"COVID-19" + 0.071*"video" + 0.070*"on" + 0.064*"been"'),
#  (2,
#   '-0.709*"to" + 0.633*"of" + -0.137*"and" + -0.123*"is" + -0.071*"for" + -0.069*"be" + -0.054*"that" + -0.051*"are" + -0.049*"from" + -0.048*"due"'),
#  (3,
#   '-0.734*"in" + 0.428*"of" + 0.363*"to" + 0.283*"a" + -0.172*"the" + -0.097*"coronavirus" + 0.046*"from" + -0.040*"was" + 0.037*"COVID-19." + 0.034*"on"'),
#  (4,
#   '0.479*"to" + 0.425*"of" + -0.407*"a" + 0.391*"in" + -0.259*"that" + -0.240*"the" + -0.213*"is" + -0.187*"and" + -0.115*"for" + -0.075*"coronavirus"')]

# %% [markdown]
# # Exercise 2
#
# Leveraging the same corpus used for LSI model generation, apply LDA modeling setting the number of topics to 5. Display the words most contributing to the those topics according to the LDA model.

# %%
from gensim.models.ldamodel import LdaModel
lda = LdaModel(processed_corpus, id2word=tm_dict, num_topics=5)
lda.print_topics(5)
# Out:
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# [(0,
#   '0.046*"in" + 0.044*"the" + 0.035*"a" + 0.035*"of" + 0.019*"coronavirus" + 0.015*"and" + 0.012*"has" + 0.012*"shows" + 0.012*"A" + 0.011*"on"'),
#  (1,
#   '0.065*"the" + 0.036*"of" + 0.034*"in" + 0.031*"to" + 0.023*"a" + 0.019*"coronavirus" + 0.014*"that" + 0.014*"A" + 0.013*"and" + 0.011*"coronavirus."'),
#  (2,
#   '0.020*"coronavirus." + 0.014*"the" + 0.014*"and" + 0.011*"to" + 0.011*"can" + 0.010*"COVID-19." + 0.009*"in" + 0.009*"of" + 0.008*"that" + 0.007*"drinking"'),
#  (3,
#   '0.028*"is" + 0.026*"to" + 0.025*"the" + 0.022*"for" + 0.021*"a" + 0.020*"and" + 0.017*"coronavirus" + 0.013*"The" + 0.013*"of" + 0.011*"that"'),
#  (4,
#   '0.022*"to" + 0.015*"in" + 0.015*"the" + 0.010*"and" + 0.010*"Coronavirus" + 0.009*"is" + 0.008*"you" + 0.008*"of" + 0.007*"are" + 0.007*"a"')]

# %% [markdown]
# # Exercise 3
#
# The top-scored words contributing to each topic (if no stopword removal is applied) are english common words (e.g., *to, for, in, of, on*..). Moreover, missing punctuation removal could be critical for topic identification. Add preliminary preprocessing step to:
# 1. **remove stopwords**
# 2. **strip punctuation**
# 3. **lowercase all words**
#
# **Suggestion**: many predefined lists of stopwords are already available. Download the stopword list of NLTK directly in your python code.

# %%
## YOUR CODE HERE

# %% [markdown]
# # Exercise 4
#
# Using [pyLDAvis]() library build an interactive visualization for the trained LDA model.

# %%
# !pip install pyLDAvis
# Out:
# Collecting pyLDAvis
#   Downloading pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from pyLDAvis) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pyLDAvis) (1.17.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pyLDAvis) (2.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from pyLDAvis) (1.5.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from pyLDAvis) (3.1.6)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from pyLDAvis) (2.14.1)
# Collecting funcy (from pyLDAvis)
#   Downloading funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pyLDAvis) (1.6.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (from pyLDAvis) (4.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from pyLDAvis) (75.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->pyLDAvis) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->pyLDAvis) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.6.0)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim->pyLDAvis) (7.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->pyLDAvis) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.17.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim->pyLDAvis) (2.1.1)
# Downloading pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 15.8 MB/s eta 0:00:00
# Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Installing collected packages: funcy, pyLDAvis
# Successfully installed funcy-2.0 pyLDAvis-3.4.1

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()

lda_display = gensimvis.prepare(lda, processed_corpus, tm_dict, sort_topics=False)
pyLDAvis.display(lda_display)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el7981320307799295523995015246" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el7981320307799295523995015246_data = {"mdsDat": {"x": [0.03228262511322807, -0.11509225660309551, 0.08280963148986746], "y": [-0.09813997172524495, 0.02505645107759325, 0.07308352064765176], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [36.95948040265661, 33.3985570207191, 29.641962576624287]}, "tinfo": {"Term": ["video", "outbreak", "cases", "police", "case", "posts", "claim", "multiple", "prevent", "confirmed", "times", "novel", "china", "water", "covid19", "predicted", "vaccine", "lockdown", "twitter", "food", "coronavirus", "created", "shows", "alongside", "health", "garlic", "10", "gates", "every", "president", "garlic", "10", "alongside", "bat", "supermarket", "white", "multiple", "taking", "cow", "steam", "gargling", "week", "salt", "juice", "holy", "viewed", "admitted", "urine", "ice", "suggest", "weed", "buried", "cold", "forward", "security", "owner", "recommends", "letter", "nationals", "prayers", "police", "posts", "twitter", "times", "hundreds", "warm", "vinegar", "3", "approval", "claim", "thousands", "water", "novel", "market", "india", "first", "video", "shows", "covid19", "shared", "coronavirus", "infected", "cure", "vaccine", "people", "died", "indian", "lockdown", "due", "virus", "government", "kill", "china", "chinese", "new", "photo", "claims", "pope", "stay", "biological", "2015", "dettol", "gave", "case", "meeting", "stopped", "humans", "them", "type", "elderly", "confirmed", "recommended", "europe", "leave", "causing", "spreading", "lions", "offers", "doses", "right", "leaked", "came", "entry", "movie", "control", "that", "corporation", "suspected", "prevention", "cases", "created", "advice", "best", "lab", "30", "prevent", "number", "discovered", "world", "laboratory", "ministry", "gates", "health", "many", "death", "bill", "covid19", "president", "coronavirus", "new", "post", "flu", "us", "audio", "says", "vaccine", "people", "chinese", "virus", "said", "media", "pandemic", "claims", "government", "china", "spread", "masks", "infected", "hospital", "italy", "novel", "ago", "professor", "source", "48", "hair", "left", "manufactured", "care", "degrees", "turned", "solution", "book", "wash", "supplies", "weeks", "isolation", "shopping", "helicopters", "throwing", "2012", "beaten", "permission", "near", "ship", "12", "supermarkets", "burning", "night", "planning", "side", "muslim", "army", "bats", "sanitizer", "advised", "dies", "day", "measures", "boiled", "predicted", "outbreak", "food", "quarantined", "every", "classes", "information", "soup", "mosque", "amid", "china", "coronavirus", "drink", "streets", "patients", "current", "prime", "video", "it", "lockdown", "quarantine", "people", "shows", "muslims", "show", "man", "minister", "new", "covid19", "spread", "hospital", "italy", "image", "chinese", "photo", "pandemic", "infected", "doctor", "due", "president", "government", "says", "virus"], "Freq": [807.0, 345.0, 214.0, 186.0, 146.0, 186.0, 280.0, 143.0, 226.0, 116.0, 197.0, 474.0, 645.0, 288.0, 2029.0, 116.0, 311.0, 295.0, 136.0, 119.0, 4078.0, 109.0, 615.0, 88.0, 281.0, 82.0, 83.0, 116.0, 113.0, 317.0, 81.77592080398912, 82.5420139284747, 86.86097149460679, 64.63631439525209, 49.32578807787171, 43.635879963049554, 140.25132846781827, 39.50435976531359, 31.679627034874493, 26.254117073335998, 44.09258974685046, 29.792577714562388, 58.04195053744025, 23.226207559834876, 21.91047979139477, 61.724363413373304, 32.19172931303142, 20.79754395574136, 25.989089335465373, 20.73285368320968, 18.396060156976255, 21.156339649647283, 48.001737018703594, 27.14910897380969, 22.051483015398418, 17.00701771960444, 31.875710698264967, 22.277348767076774, 16.64970930523005, 23.22492466718375, 179.07709824182052, 177.96897097250528, 125.74616675408738, 176.46208489951593, 61.53273611392885, 55.96812810609336, 38.72002511175168, 32.7450228471218, 28.777147195043145, 233.87793637625225, 112.20204675109315, 225.6045306461311, 343.7840469034819, 72.41694335671193, 193.09889958245174, 116.26117749550781,  ...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# # Exercise 5

# %% [markdown]
# We can also use BERTopic to solve the topic modeling task.
#
# BERTopic is a topic modeling technique that leverages transformers and c-TF-IDF to create dense clusters allowing for easily interpretable topics whilst keeping important words in the topic descriptions.

# %%
# !pip install bertopic
# !pip install sympy==1.12
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.12/dist-packages (0.17.4)
# Requirement already satisfied: hdbscan>=0.8.29 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.8.41)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.5.11)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.12/dist-packages (from bertopic) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (5.24.1)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (1.6.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from bertopic) (5.2.3)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.12/dist-packages (from bertopic) (4.67.3)
# Requirement already satisfied: llvmlite>0.36.0 in /usr/local/lib/python3.12/dist-packages (from bertopic) (0.43.0)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from hdbscan>=0.8.29->bertopic) (1.17.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from hdbscan>=0.8.29->bertopic) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->bertopic) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.5->bertopic) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=4.7.0->bertopic) (9.1.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=4.7.0->bertopic) (26.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0->bertopic) (3.6.0)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (5.0.0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.5.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (2.10.0+cpu)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.15.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.5.0->bertopic) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.12/dist-packages (from umap-learn>=0.5.0->bertopic) (0.6.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.24.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.3.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (0.24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.17.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (75.2.0)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.7.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (0.1.2)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 23.3 MB/s eta 0:00:00
# Installing collected packages: sympy
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.12
#     Uninstalling sympy-1.12:
#       Successfully uninstalled sympy-1.12
# Successfully installed sympy-1.14.0
# Collecting sympy==1.12
#   Using cached sympy-1.12-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.12/dist-packages (from sympy==1.12) (1.3.0)
# Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Installing collected packages: sympy
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.10.0+cpu requires sympy>=1.13.3, but you have sympy 1.12 which is incompatible.
# Successfully installed sympy-1.12

# %%
from bertopic import BERTopic

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(["headlines"].tolist()[:1000])
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                       Name  \
# 0      -1    257                            -1_of_the_to_in
# 1       0    150             0_cure_and_covid19_coronavirus
# 2       1     82                 1_covid19_no_brazilian_the
# 3       2     75                  2_masks_mask_wearing_face
# 4       3     48          3_hospital_patients_covid19_video
# 5       4     43            4_gates_bill_melinda_foundation
# 6       5     32               5_more_is_infectious_covid19
# 7       6     31            6_vaccine_ukrainian_the_against
# 8       7     29              7_positive_test_tests_barrier
# 9       8     28                   8_photo_baby_which_shows
# 10      9     25             9_berlin_august_german_protest
# 11     10     19            10_5g_activated_rna_digitizable
# 12     11     18               11_boy_predicted_indian_2019
# 13     12     18         12_potency_losing_coronavirus_said
# 14     13     16    13_thermometers_infrared_damage_neurons
# 15     14     16    14_laboratory_created_china_coronavirus
# 16     15     16              15_lockdown_ukraine_june_news
# 17     16     15               16_pedro_spanish_the_sanchez
# 18     17     15                  17_bodies_dead_mexico_sea
# 19     18     15        18_chinese_vaccine_developed_tested
# 20     19     14           19_secretary_education_die_betsy
# 21     20     14           20_picture_italian_italy_stating
# 22     21     13  21_asymptomatic_official_coronavirus_dont
# 23     22     11               22_doctor_hospital_died_muiz
#
#                                        Representation  \
# 0   [of, the, to, in, that, is, covid19, coronavir...
# 1   [cure, and, covid19, coronavirus, the, hydroxy...
# 2   [covid19, no, brazilian, the, cases, of, death...
# 3   [masks, mask, wearing, face, oxygen, and, that...
# 4   [hospital, patients, covid19, video, patient, ...
# 5   [gates, bill, melinda, foundation, vaccines, f...
# 6   [more, is, infectious, covid19, contagious, mu...
# 7   [vaccine, ukrainian, the, against, will, of, i...
# 8   [positive, test, tests, barrier, swabs, covid1...
# 9   [photo, baby, which, shows, show, covid19, of,...
# 10  [berlin, august, german, protest, against, 1st...
# 11  [5g, activated, rna, digitizable, new, recover...
# 12  [boy, predicted, indian, 2019, coronavirus, vi...
# 13  [potency, losing, coronavirus, said, epidemic,...
# 14  [thermometers, infrared, damage, neurons, can,...
# 15  [laboratory, created, china, coronavirus, ghan...
# 16  [lockdown, ukraine, june, news, 2020, has, 201...
# 17  [pedro, spanish, the, sanchez, phrase, ministe...
# 18  [bodies, dead, mexico, sea, patients, are, had...
# 19  [chinese, vaccine, developed, tested, coronava...
# 20  [secretary, education, die, betsy, devos, scho...
# 21  [picture, italian, italy, stating, parties, ne...
# 22  [asymptomatic, official, coronavirus, dont, tr...
# 23  [doctor, hospital, died, muiz, syrian, egyptia...
#
#                                   Representative_Docs
# 0   [For a couple of days a message has been circu...
# 1   [The cure for coronavirus: ginger, lemon, onio...
# 2   [According to a Greek journalist COVID-19 is n...
# 3   [A video of an excerpt from an American televi...
# 4   [Doctors of a hospital in New Zealand are chee...
# 5   [Claims from Spanish singer Miguel Bosé on the...
# 6   [COVID-19 is mutating and is now more contagio...
# 7   [A news article claims 30% of Ukrainian patien...
# 8   [Critics say it is wrong to use of PCR tests f...
# 9   [A photo that shows Brazilian president Jair B...
# 10  [A picture allegedly showing a large crowd gat...
# 11  [The new coronavirus vaccine has "digitizable ...
# 12  [A video of a 14-year-old Indian boy named Abh...
# 13  [WHO said that the novel coronavirus is losing...
# 14  [Infrared thermometers kill neurons., Infrared...
# 15  ["Plandemia": This video claims that the coron...
# 16  [To be able to manipulate the lockdown measure...
# 17  [Some statements by the American political sci...
# 18  [Dead bodies of COVID-19 victims are thrown in...
# 19  [WHO says Coronavac, vaccine produced by Sinov...
# 20  [US Education Secretary Betsy DeVos said child...
# 21  [A picture stating that the governing parties ...
# 22  [Top Georgian health official Gamkrelidze said...
# 23  [A picture of the Egyptian doctor, Mohamed Has...

# %%
filtered_corpus = [" ".join(s) for s in rs_corpus]

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(filtered_corpus[:1000])
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                           Name  \
# 0      -1    254       -1_covid19_coronavirus_pandemic_positive
# 1       0     89                      0_masks_mask_wearing_face
# 2       1     76                1_coronavirus_lemon_cure_ginger
# 3       2     47              2_hospital_video_patients_patient
# 4       3     45              3_brazilian_brazil_death_recorded
# 5       4     40          4_vaccine_developed_coronavac_chinese
# 6       5     29    5_hydroxychloroquine_chloroquine_drug_paulo
# 7       6     27           6_covid19_mutating_contagious_before
# 8       7     24                7_hospital_died_doctor_patients
# 9       8     23                  8_facebook_times_shared_women
# 10      9     22                     9_tests_barrier_test_swabs
# 11     10     21                 10_cases_number_deaths_covid19
# 12     11     21             11_happened_laboratory_odd_created
# 13     12     21                12_picture_berlin_german_august
# 14     13     20                  13_lockdown_ukraine_june_news
# 15     14     20                 14_5g_activated_rna_technology
# 16     15     20                   15_nipah_predicted_named_boy
# 17     16     18             16_tunisia_african_border_european
# 18     17     18               17_colombian_global_company_scam
# 19     18     17                 18_self_coronavirus_test_check
# 20     19     17                     19_bill_gates_vaccines_dna
# 21     20     17             20_italy_newspaper_italian_article
# 22     21     16                   21_whatsapp_1918_flu_message
# 23     22     14           22_doctors_fraud_protesters_occupied
# 24     23     14        23_thermometers_infrared_damage_neurons
# 25     24     13  24_ivermectin_azithromycin_australia_symptoms
# 26     25     13                      25_bodies_mexico_sea_dead
# 27     26     12                      26_baby_mother_show_image
# 28     27     11              27_taiwan_electrical_energy_bonus
# 29     28     11                    28_melinda_fauci_2015_gates
# 30     29     10                 29_buenos_aires_argentina_drop
#
#                                        Representation  \
# 0   [covid19, coronavirus, pandemic, positive, vac...
# 1   [masks, mask, wearing, face, oxygen, work, cau...
# 2   [coronavirus, lemon, cure, ginger, prevent, cu...
# 3   [hospital, video, patients, patient, shows, co...
# 4   [brazilian, brazil, death, recorded, denied, r...
# 5   [vaccine, developed, coronavac, chinese, abort...
# 6   [hydroxychloroquine, chloroquine, drug, paulo,...
# 7   [covid19, mutating, contagious, before, diseas...
# 8   [hospital, died, doctor, patients, coronavirus...
# 9   [facebook, times, shared, women, posts, multip...
# 10  [tests, barrier, test, swabs, bloodbrain, pcr,...
# 11  [cases, number, deaths, covid19, testing, comp...
# 12  [happened, laboratory, odd, created, china, pr...
# 13  [picture, berlin, german, august, 1st, conte, ...
# 14  [lockdown, ukraine, june, news, zee, robredo, ...
# 15  [5g, activated, rna, technology, amplified, di...
# 16  [nipah, predicted, named, boy, outbreak, india...
# 17  [tunisia, african, border, european, decided, ...
# 18  [colombian, global, company, scam, due, citize...
# 19  [self, coronavirus, test, check, used, symptom...
# 20  [bill, gates, vaccines, dna, vaccine, surveil,...
# 21  [italy, newspaper, italian, article, stating, ...
# 22  [whatsapp, 1918, flu, message, vaccine, it, wa...
# 23  [doctors, fraud, protesters, occupied, houses,...
# 24  [thermometers, infrared, damage, neurons, lase...
# 25  [ivermectin, azithromycin, australia, symptoms...
# 26  [bodies, mexico, sea, dead, patients, depicts,...
# 27  [baby, mother, show, image, leone, sierra, pre...
# 28  [taiwan, electrical, energy, bonus, economic, ...
# 29  [melinda, fauci, 2015, gates, obama, lab, wuha...
# 30  [buenos, aires, argentina, drop, kicillof, axe...
#
#                                   Representative_Docs
# 0   [according greek journalist covid19 pandemic s...
# 1   [video excerpt american television program pre...
# 2   [lemon ginger garlic cures coronavirus, cure c...
# 3   [doctors hospital new zealand cheering video c...
# 4   [brazilian supreme court denied order army hos...
# 5   [oxford universitys vaccine made using cells a...
# 6   [stella immanuel claims drug combination hydro...
# 7   [covid19 mutating contagious before, centers d...
# 8   [egyptian doctor publishes picture hands colle...
# 9   [corona cooking survey shows men women bake of...
# 10  [critics say wrong use pcr tests detect covid1...
# 11  [in real sense oklahoma has flattened curve … ...
# 12  [president ghana said coronavirus created labo...
# 13  [picture allegedly showing large crowd gathere...
# 14  [able manipulate lockdown measures ukraine cla...
# 15  [new coronavirus vaccine digitizable rna activ...
# 16  [video 14yearold indian boy named abhigya anan...
# 17  [world health organization considers tunisia b...
# 18  [email colombian ministry health informing cit...
# 19  [cnbc reported coronavirus patients without sy...
# 20  [bill gates said covid19 vaccine permanently c...
# 21  [article stating utility bills increased covid...
# 22  [facebook post claiming 50 million people died...
# 23  [german doctors called pandemic fake, 63 inten...
# 24  [infrared thermometers kill neurons, infrared ...
# 25  [symptoms covid19 take azithromycin ivermectin...
# 26  [chinese authorities dumped dead bodies sea bo...
# 27  [image supposedly shows results vaccination ca...
# 28  [economic bonus low electrical energy consumpt...
# 29  [photo claims show dr fauci melinda gates bara...
# 30  [axel kicillof governor province buenos aires ...

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a9998193-edc2-46e0-920d-a9d91722b14d" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9998193-edc2-46e0-920d-a9d91722b14d")) {                    Plotly.newPlot(                        "a9998193-edc2-46e0-920d-a9d91722b14d",                        [{"customdata":[[0,"masks | mask | wearing | face | oxygen",89],[1,"coronavirus | lemon | cure | ginger | prevent",76],[2,"hospital | video | patients | patient | shows",47],[3,"brazilian | brazil | death | recorded | denied",45],[4,"vaccine | developed | coronavac | chinese | aborted",40],[5,"hydroxychloroquine | chloroquine | drug | paulo | use",29],[6,"covid19 | mutating | contagious | before | disease",27],[7,"hospital | died | doctor | patients | coronavirus",24],[8,"facebook | times | shared | women | posts",23],[9,"tests | barrier | test | swabs | bloodbrain",22],[10,"cases | number | deaths | covid19 | testing",21],[11,"happened | laboratory | odd | created | china",21],[12,"picture | berlin | german | august | 1st",21],[13,"lockdown | ukraine | june | news | zee",20],[14,"5g | activated | rna | technology | amplified",20],[15,"nipah | predicted | named | boy | outbreak",20],[16,"tunisia | african | border | european | decided",18],[17,"colombian | global | company | scam | due",18],[18,"self | coronavirus | test | check | used",17],[19,"bill | gates | vaccines | dna | vaccine",17],[20,"italy | newspaper | italian | article | stating",17],[21,"whatsapp | 1918 | flu | message | vaccine",16],[22,"doctors | fraud | protesters | occupied | houses",14],[23,"thermometers | infrared | damage | neurons | laser",14],[24,"ivermectin | azithromycin | australia | symptoms | ibuprofen",13],[25,"bodies | mexico | sea | dead | patients",13],[26,"baby | mother | show | image | leone",12],[27,"taiwan | electrical | energy | bonus | economic",11],[28,"melinda | fauci | 2015 | gates | obama",11],[29,"buenos | aires | argentina | drop | kicillof",10]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[89,76,47,45,40,29,27,24,23,22,21,21,21,20,20,20,18,18,17,17,17,16,14,14,13,13,12,11,11,10],"sizemode":"area","sizeref":0.055625,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[-3.1974149,5.9888577,-7.83053,6.6227884,-8.038042,-7.673108,-7.3197665,6.3784647,-3.6446753,-7.4670696,-7.3630204,6.3081536,-8.165613,6.227108,5.723448,6.2055597,-8.50416,6.4851017,5.783701,-8.289994,-8.424844,-3.459001,-7.9310675,-2.990522,5.691644,6.614776,-7.053252,5.9514713,-8.069033,6.3318057],"xaxis":"x","y":[-15.667134,-4.9491453,9.493953,10.968134,11.12455,10.5090275,10.252287,-6.020489,-15.22035,10.071822,10.463314,-5.347513,8.8049755,11.364169,-5.5889163,-5.4065337,8.457361,11.106415,-5.2883735,11.442562,8.528457,-15.406263,9.088362,-15.872992,-4.702206,-6.259243,10.422387,11.63968,11.625032,11.259807],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,3 ...

# %% [markdown]
# ### **EXTRA**
#
# Use one of the sentence embedding model from the previous practice to cluster the following list of documents:
#
# ```python
# docs = [
#     "Apple unveils new AI features for iPhone users",
#     "Microsoft launches a new cloud security platform",
#     "Stock markets fall as inflation fears return",
#     "Investors expect another interest rate increase",
#     "Real Madrid wins after a dramatic extra-time goal",
#     "Barcelona signs a new striker for next season",
#     "Scientists discover a new method for battery recycling",
#     "Researchers develop a model to detect fake news",
#     "Parliament debates a new immigration law",
#     "Government approves an education reform package",
#     "NASA prepares its next mission to the Moon",
#     "SpaceX tests a new reusable rocket system",
# ]
# ```
#
# Are the documents grouped correctly? Can you think about a way to assign a label to each cluster?
#
# **Suggestions:**
# 1.   Create the embedding of each document
# 2.   Pass the embedding to clustering algorithm
# 3.   Manually check cluster quality

# %%
## YOUR CODE HERE
